# %% [markdown]
# # Articles - Pipeline Notebook
#
# Dataset: `articles.csv`

# %% [markdown]
# ## 0 - Setup: SparkSession

# %%
from src.spark_utils import create_spark_session

spark = create_spark_session('Articles-Notebook')
print('SparkSession ready. Version:', spark.version)
# Out:
# SparkSession ready. Version: 3.2.0

# %% [markdown]
# ## Stage 3 - Extraction

# %%
from src.articles.extraction import run_extraction

raw_df = run_extraction(spark, raw_dir=str(PROJECT_ROOT / 'data' / 'raw'))
# Out:
# === EXTRACTION: /app/data/raw/articles.csv ===
# root
#  |-- article_id: string (nullable = true)
#  |-- product_code: integer (nullable = true)
#  |-- prod_name: string (nullable = true)
#  |-- product_type_no: integer (nullable = true)
#  |-- product_type_name: string (nullable = true)
#  |-- product_group_name: string (nullable = true)
#  |-- graphical_appearance_no: integer (nullable = true)
#  |-- graphical_appearance_name: string (nullable = true)
#  |-- colour_group_code: integer (nullable = true)
#  |-- colour_group_name: string (nullable = true)
#  |-- perceived_colour_value_id: integer (nullable = true)
#  |-- perceived_colour_value_name: string (nullable = true)
#  |-- perceived_colour_master_id: integer (nullable = true)
#  |-- perceived_colour_master_name: string (nullable = true)
#  |-- department_no: integer (nullable = true)
#  |-- department_name: string (nullable = true)
#  |-- index_code: string (nullable = true)
#  |-- index_name: string (nullable = true)
#  |-- index_group_no: integer (nullable = true)
#  |-- index_group_name: string (nullable = true)
#  |-- section_no: integer (nullable = true)
#  |-- section_name: string (nullable = true)
#  |-- garment_group_no: integer (nullable = true)
#  |-- garment_group_name: string (nullable = true)
#  |-- detail_desc: string (nullable = true)
#
# rows: 105,542  cols: ['article_id', 'product_code', 'prod_name', 'product_type_no', 'product_type_name', 'product_group_name', 'graphical_appearance_no', 'graphical_appearance_name', 'colour_group_code', 'colour_group_name', 'perceived_colour_value_id', 'perceived_colour_value_name', 'perceived_colour_master_id', 'perceived_colour_master_name', 'department_no', 'department_name', 'index_code', 'index_name', 'index_group_no', 'index_group_name', 'section_no', 'section_name', 'garment_group_no', 'garment_group_name', 'detail_desc']
# +----------+------------+-----------------+---------------+-----------------+------------------+-----------------------+-------------------------+-----------------+-----------------+-------------------------+---------------------------+--------------------------+----------------------------+-------------+---------------+----------+----------------+--------------+----------------+----------+----------------------+----------------+------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |article_id|product_code|prod_name        |product_type_no|product_type_name|product_group_name|graphical_appearance_no|graphical_appearance_name|colour_group_code|colour_group_name|perceived_colour_value_id|perceived_colour_value_name|perceived_colour_master_id|perceived_colour_master_name|department_no|department_name|index_code|index_name      |index_group_no|index_group_name|section_no|section_name          |garment_group_no|garment_group_name|detail_desc                                                                                                                                                                                                                                     |
# +----------+------------+-----------------+---------------+-----------------+------------------+-----------------------+-------------------------+-----------------+-----------------+-------------------------+---------------------------+--------------------------+----------------------------+-------------+---------------+----------+----------------+--------------+----------------+----------+----------------------+----------------+------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |0108775015|108775      |Strap top        |253            |Vest top         |Garment Upper body|1010016                |Solid                    |9                |Black            |4                        |Dark                       |5                         |Black                       |1676         |Jersey Basic   |A         |Ladieswear      |1             |Ladieswear      |16        |Womens Everyday Basics|1002            |Jersey Basic      |Jersey top with narrow shoulder straps.                                                                                                                                                                                                         |
# |0108775044|108775      |Strap top        |253            |Vest top         |Garment Upper body|1010016                |Solid                    |10               |White            |3                        |Light                      |9                         |White                       |1676         |Jersey Basic   |A         |Ladieswear      |1             |Ladieswear      |16        |Womens Everyday Basics|1002            |Jersey Basic      |Jersey top with narrow shoulder straps.                                                                                                                                                                                                         |
# |0108775051|108775      |Strap top (1)    |253            |Vest top         |Garment Upper body|1010017                |Stripe                   |11               |Off White        |1                        |Dusty Light                |9                         |White                       |1676         |Jersey Basic   |A         |Ladieswear      |1             |Ladieswear      |16        |Womens Everyday Basics|1002            |Jersey Basic      |Jersey top with narrow shoulder straps.                                                                                                                                                                                                         |
# |0110065001|110065      |OP T-shirt (Idro)|306            |Bra              |Underwear         |1010016                |Solid                    |9                |Black            |4                        |Dark                       |5                         |Black                       |1339         |Clean Lingerie |B         |Lingeries/Tights|1             |Ladieswear      |61        |Womens Lingerie       |1017            |Under-, Nightwear |Microfibre T-shirt bra with underwired, moulded, lightly padded cups that shape the bust and provide good support. Narrow adjustable shoulder straps and a narrow hook-and-eye fastening at the back. Without visible seams for greater comfort.|
# |0110065002|110065      |OP T-shirt (Idro)|306            |Bra              |Underwear         |1010016                |Solid                    |10               |White            |3                        |Light                      |9                         |White                       |1339         |Clean Lingerie |B         |Lingeries/Tights|1             |Ladieswear      |61        |Womens Lingerie       |1017            |Under-, Nightwear |Microfibre T-shirt bra with underwired, moulded, lightly padded cups that shape the bust and provide good support. Narrow adjustable shoulder straps and a narrow hook-and-eye fastening at the back. Without visible seams for greater comfort.|
# +----------+------------+-----------------+---------------+-----------------+------------------+-----------------------+-------------------------+-----------------+-----------------+-------------------------+---------------------------+--------------------------+----------------------------+-------------+---------------+----------+----------------+--------------+----------------+----------+----------------------+----------------+------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# ## Stage 4 - Preprocessing

# %%
from src.articles.preprocessing import run_preprocessing

clean_df = run_preprocessing(raw_df)
print('Rows after preprocessing:', clean_df.count())
# Out:
# === PREPROCESSING articles.csv ===
#
# --- Step 1 - general stats ---
# rows: 105,542, cols: 25
# columns: ['article_id', 'product_code', 'prod_name', 'product_type_no', 'product_type_name', 'product_group_name', 'graphical_appearance_no', 'graphical_appearance_name', 'colour_group_code', 'colour_group_name', 'perceived_colour_value_id', 'perceived_colour_value_name', 'perceived_colour_master_id', 'perceived_colour_master_name', 'department_no', 'department_name', 'index_code', 'index_name', 'index_group_no', 'index_group_name', 'section_no', 'section_name', 'garment_group_no', 'garment_group_name', 'detail_desc']
# 26/03/16 18:22:52 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +-------+--------------------+------------------+--------------------------+------------------+-----------------+------------------+-----------------------+-------------------------+------------------+-----------------+-------------------------+---------------------------+--------------------------+----------------------------+------------------+------------------+----------+----------------+-----------------+----------------+-----------------+------------+------------------+-----------------------------+--------------------------------------------------------------------------+
# |summary|article_id          |product_code      |prod_name                 |product_type_no   |product_type_name|product_group_name|graphical_appearance_no|graphical_appearance_name|colour_group_code |colour_group_name|perceived_colour_value_id|perceived_colour_value_name|perceived_colour_master_id|perceived_colour_master_name|department_no     |department_name   |index_code|index_name      |index_group_no   |index_group_name|section_no       |section_name|garment_group_no  |garment_group_name           |detail_desc                                                               |
# +-------+--------------------+------------------+--------------------------+------------------+-----------------+------------------+-----------------------+-------------------------+------------------+-----------------+-------------------------+---------------------------+--------------------------+----------------------------+------------------+------------------+----------+----------------+-----------------+----------------+-----------------+------------+------------------+-----------------------------+--------------------------------------------------------------------------+
# |count  |105542              |105542            |105542                    |105542            |105542           |105542            |105542                 |105542                   |105542            |105542           |105542                   |105542                     |105542                    |105542                      |105542            |105542            |105542    |105542          |105542           |105542          |105542           |105542      |105542            |105542                       |105126                                                                    |
# |mean   |6.984245690969188E8 |698424.5633776127 |null                      |234.86187489340736|null             |null              |1009515.0757234087     |null                     |32.23382160656421 |null             |3.206183320384302        |null                       |7.807972181690701         |null                        |4532.77783252165  |null              |null      |null            |3.171533607473802|null            |42.66421898391162|null        |1010.4382899698699|null                         |null                                                                      |
# |stddev |1.2846238133616123E8|128462.38443205012|null                      |75.0493080295674  |null             |null              |22413.585777875127     |null                     |28.086154123050108|null             |1.563838925432253        |null                       |5.37672700815203          |null                        |2712.6920114304908|null              |null      |null            |4.353234433974898|null            |23.26010495890632|null        |6.731023181573535 |null                         |null                                                                      |
# |min    |0108775015          |108775            |& Denim Boyfriend LW denim|-1                |Accessories set  |Accessories       |-1                     |All over pattern         |-1                |Beige            |-1                       |Bright                     |-1                        |Beige                       |1201              |AK Bottoms        |A         |Baby Sizes 50-98|1                |Baby/Children   |2                |Baby Boy    |1001              |Accessories                  |"Alice band in metal with a ""PARTY TIME 2017"" text at the top."         |
# |max    |0959461001          |959461            |Åsa Dress                 |762               |Zipper head      |Unknown           |1010029                |Unknown                  |93                |Yellowish Brown  |7                        |Unknown                    |20                        |undefined                   |9989              |Young boy Swimwear|S         |Sport           |26               |Sport           |97               |Young Girl  |1025              |Woven/Jersey/Knitted mix Baby|{b> <b}Knitted socks in cotton-blend terry. The cotton content is organic.|
# +-------+--------------------+------------------+--------------------------+------------------+-----------------+------------------+-----------------------+-------------------------+------------------+-----------------+-------------------------+---------------------------+--------------------------+----------------------------+------------------+------------------+----------+----------------+-----------------+----------------+-----------------+------------+------------------+-----------------------------+--------------------------------------------------------------------------+
#
#
# --- Step 2 - type casting and text normalization ---
# casts and lowercasing complete
# root
#  |-- article_id: string (nullable = true)
#  |-- product_code: integer (nullable = true)
#  |-- prod_name: string (nullable = true)
#  |-- product_type_no: integer (nullable = true)
#  |-- product_type_name: string (nullable = true)
#  |-- product_group_name: string (nullable = true)
#  |-- graphical_appearance_no: integer (nullable = true)
#  |-- graphical_appearance_name: string (nullable = true)
#  |-- colour_group_code: integer (nullable = true)
#  |-- colour_group_name: string (nullable = true)
#  |-- perceived_colour_value_id: integer (nullable = true)
#  |-- perceived_colour_value_name: string (nullable = true)
#  |-- perceived_colour_master_id: integer (nullable = true)
#  |-- perceived_colour_master_name: string (nullable = true)
#  |-- department_no: integer (nullable = true)
#  |-- department_name: string (nullable = true)
#  |-- index_code: string (nullable = true)
#  |-- index_name: string (nullable = true)
#  |-- index_group_no: integer (nullable = true)
#  |-- index_group_name: string (nullable = true)
#  |-- section_no: integer (nullable = true)
#  |-- section_name: string (nullable = true)
#  |-- garment_group_no: integer (nullable = true)
#  |-- garment_group_name: string (nullable = true)
#  |-- detail_desc: string (nullable = true)
#
#
# --- Step 3 - feature informativeness ---
# column                           distinct      null%
# --------------------------------------------------------
# article_id                        105,542      0.00%
# product_code                       47,224      0.00%
# prod_name                          44,087      0.00%
# product_type_no                       132      0.00%
# product_type_name                     130      0.00%
# product_group_name                     19      0.00%
# graphical_appearance_no                30      0.00%
# graphical_appearance_name              30      0.00%
# colour_group_code                      50      0.00%
# colour_group_name                      50      0.00%
# perceived_colour_value_id               8      0.00%
# perceived_colour_value_name             8      0.00%
# perceived_colour_master_id             20      0.00%
# perceived_colour_master_name           20      0.00%
# department_no                         299      0.00%
# department_name                       248      0.00%
# index_code                             10      0.00%
# index_name                             10      0.00%
# index_group_no                          5      0.00%
# index_group_name                        5      0.00%
# section_no                             57      0.00%
# section_name                           56      0.00%
# garment_group_no                       21      0.00%
# garment_group_name                     21      0.00%
# detail_desc                        43,396      0.39%
#
# --- Step 4 - null handling for required business fields ---
# required columns checked: ['article_id', 'prod_name', 'product_type_name', 'product_group_name', 'department_name', 'index_name', 'section_name', 'garment_group_name']
# before: 105,542  after: 105,542  removed: 0
#
# --- Step 5 - deduplicate by article_id ---
# [Stage 253:>                                                      (0 + 10) / 10]
# before: 105,542  after: 105,542  removed: 0
#
# done.
# [Stage 257:=========================>                               (4 + 5) / 9]
# Rows after preprocessing: 105542

# %% [markdown]
# ## Save Cleaned Data

# %%
OUT_PATH = str(PROJECT_ROOT / 'data' / 'processed' / 'articles')
clean_df.write.mode('overwrite').parquet(OUT_PATH)
print(f'Saved to: {OUT_PATH}')
spark.read.parquet(OUT_PATH).show(5, truncate=False)
# Out:
# Saved to: /app/data/processed/articles
# +----------+------------+--------------------+---------------+------------------------+------------------+-----------------------+-------------------------+-----------------+-----------------+-------------------------+---------------------------+--------------------------+----------------------------+-------------+---------------+----------+----------------+--------------+----------------+----------+-----------------------------+----------------+------------------+-------------------------------------------------------------------------------------------------------------------------------------+
# |article_id|product_code|prod_name           |product_type_no|product_type_name       |product_group_name|graphical_appearance_no|graphical_appearance_name|colour_group_code|colour_group_name|perceived_colour_value_id|perceived_colour_value_name|perceived_colour_master_id|perceived_colour_master_name|department_no|department_name|index_code|index_name      |index_group_no|index_group_name|section_no|section_name                 |garment_group_no|garment_group_name|detail_desc                                                                                                                          |
# +----------+------------+--------------------+---------------+------------------------+------------------+-----------------------+-------------------------+-----------------+-----------------+-------------------------+---------------------------+--------------------------+----------------------------+-------------+---------------+----------+----------------+--------------+----------------+----------+-----------------------------+----------------+------------------+-------------------------------------------------------------------------------------------------------------------------------------+
# |0108775015|108775      |strap top           |253            |vest top                |garment upper body|1010016                |solid                    |9                |black            |4                        |dark                       |5                         |black                       |1676         |jersey basic   |a         |ladieswear      |1             |ladieswear      |16        |womens everyday basics       |1002            |jersey basic      |jersey top with narrow shoulder straps.                                                                                              |
# |0118458029|118458      |jerry jogger bottoms|272            |trousers                |garment lower body|1010010                |melange                  |8                |dark grey        |4                        |dark                       |12                        |grey                        |5883         |jersey basic   |f         |menswear        |3             |menswear        |26        |men underwear                |1002            |jersey basic      |trousers in sweatshirt fabric with an elasticated drawstring waist, side pockets, a back pocket and ribbed hems. soft brushed inside.|
# |0118458039|118458      |jerry jogger bottoms|272            |trousers                |garment lower body|1010010                |melange                  |73               |dark blue        |2                        |medium dusty               |6                         |lilac purple                |5883         |jersey basic   |f         |menswear        |3             |menswear        |26        |men underwear                |1002            |jersey basic      |trousers in sweatshirt fabric with an elasticated drawstring waist, side pockets, a back pocket and ribbed hems. soft brushed inside.|
# |0129085001|129085      |pirate leggings (1) |273            |leggings/tights         |garment lower body|1010016                |solid                    |9                |black            |4                        |dark                       |5                         |black                       |1676         |jersey basic   |a         |ladieswear      |1             |ladieswear      |16        |womens everyday basics       |1002            |jersey basic      |3/4-length leggings in stretch jersey with an elasticated waist.                                                                     |
# |0141661022|141661      |velour pyjama       |295            |pyjama jumpsuit/playsuit|nightwear         |1010002                |application/3d           |10               |white            |3                        |light                      |9                         |white                       |6563         |baby nightwear |g         |baby sizes 50-98|4             |baby/children   |44        |baby essentials & complements|1017            |under-, nightwear |velour pyjamas with an appliqué detail at the front and on the feet, and press-studs along one side and leg.                         |
# +----------+------------+--------------------+---------------+------------------------+------------------+-----------------------+-------------------------+-----------------+-----------------+-------------------------+---------------------------+--------------------------+----------------------------+-------------+---------------+----------+----------------+--------------+----------------+----------+-----------------------------+----------------+------------------+-------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
spark.stop()
print('SparkSession stopped.')
# Out:
# SparkSession stopped.
